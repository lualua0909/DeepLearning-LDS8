# %% [markdown]
# <a href="https://colab.research.google.com/github/lualua0909/DeepLearning-LDS8/blob/main/Week_5/Chapter9_demo_MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 5.2 MB/s
# ...

# %%
import mtcnn

mtcnn.__version__
# Out:
# '0.1.0'

# %%
from mtcnn.mtcnn import MTCNN
import cv2
from skimage import io
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image = io.imread('/content/drive/MyDrive/Cung cap Chapter9/FaceDetection/people.jpg')
plt.imshow(image)

# %%
detector = MTCNN()
result = detector.detect_faces(image)
result
# Out:
# [{'box': [38, 190, 295, 402],
#   'confidence': 0.9999997615814209,
#   'keypoints': {'left_eye': (118, 347),
#    'mouth_left': (99, 481),
#    'mouth_right': (243, 499),
#    'nose': (178, 457),
#    'right_eye': (259, 368)}},
#  {'box': [836, 199, 280, 325],
#   'confidence': 0.999970555305481,
#   'keypoints': {'left_eye': (907, 325),
#    'mouth_left': (935, 439),
#    'mouth_right': (1061, 415),
#    'nose': (978, 377),
#    'right_eye': (1030, 298)}},
#  {'box': [465, 366, 226, 288],
#   'confidence': 0.9995284080505371,
#   'keypoints': {'left_eye': (528, 499),
#    'mouth_left': (548, 591),
#    'mouth_right': (659, 559),
#    'nose': (599, 536),
#    'right_eye': (630, 469)}},
#  {'box': [817, 812, 20, 26],
#   'confidence': 0.7720900177955627,
#   'keypoints': {'left_eye': (823, 822),
#    'mouth_left': (823, 833),
#    'mouth_right': (830, 833),
#    'nose': (827, 828),
#    'right_eye': (831, 821)}}]

# %%
bounding_box = result[0]['box']
keypoints = result[0]['keypoints']

# %%
for p in result:
  bounding_box = p['box']
  keypoints = p['keypoints']

  cv2.rectangle(image, (bounding_box[0], bounding_box[1]),
                (bounding_box[0] + bounding_box[2], bounding_box[1] + bounding_box[3]),
                (255,0,0), 2)
  cv2.circle(image, (keypoints['left_eye']), 5, (0,255,0), 10)
  cv2.circle(image, (keypoints['right_eye']), 5, (0,255,0), 10)
  cv2.circle(image, (keypoints['nose']), 5, (0,255,0), 10)
  cv2.circle(image, (keypoints['mouth_left']), 5, (0,255,0), 10)
  cv2.circle(image, (keypoints['mouth_right']), 5, (0,255,0), 10)

# %%
plt.imshow(image)

# %%
def mtcnn_detect_faces(_image):
  detector = MTCNN()
  result = detector.detect_faces(_image)
  for p in result:
    bounding_box = p['box']
    keypoints = p['keypoints']

    cv2.rectangle(_image, (bounding_box[0], bounding_box[1]),
                  (bounding_box[0] + bounding_box[2], bounding_box[1] + bounding_box[3]),
                  (255,0,0), 2)
    cv2.circle(_image, (keypoints['left_eye']), 5, (0,255,0), 10)
    cv2.circle(_image, (keypoints['right_eye']), 5, (0,255,0), 10)
    cv2.circle(_image, (keypoints['nose']), 5, (0,255,0), 10)
    cv2.circle(_image, (keypoints['mouth_left']), 5, (0,255,0), 10)
    cv2.circle(_image, (keypoints['mouth_right']), 5, (0,255,0), 10)
  
  return _image

# %%
img = io.imread('https://cdn1.tuoitre.vn/zoom/600_315/2021/10/20/nhung-kate-0-1634702470008217701283-crop-1634702486294924247113.jpeg')
plt.imshow(img)

# %%
mtcnn_detect_faces(img)
plt.imshow(img)
